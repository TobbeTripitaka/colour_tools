# %%
from lib.colour_swap import *

colours = {'#000000': '#140E00', '#FFFFFF': '#E8D9A8'}

colour_swap('qr_2025.png', 
            'qr_2025_warm.png', 
                colours, range_tolerance=5)
# Out:
# Color swap complete: /Users/toby/Library/CloudStorage/Dropbox/Apps/Overleaf/CliC_Aq2/fig/losing_2025_poster.png
